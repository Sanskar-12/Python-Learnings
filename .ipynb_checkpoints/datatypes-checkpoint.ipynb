# %% [markdown]
# # Datatypes

# %% [markdown]
# ## Numbers

# %%
10+2
# Out:
# 12

# %%
10%2
# Out:
# 0

# %%
10 * 'str'
# Out:
# 'strstrstrstrstrstrstrstrstrstr'

# %%
10 ** 2
# Out:
# 100

# %%
type(1)
# Out:
# int

# %% [markdown]
# ## Strings

# %%
"Sanskar"
# Out:
# 'Sanskar'

# %%
'Sanskar'
# Out:
# 'Sanskar'

# %%
type("Sanskar")
# Out:
# str

# %% [markdown]
# ## Variable Assignment

# %%
a=10

# %%
type(a)
# Out:
# int

# %%
print(a)
# Out:
# 10

# %%
first_name="Sanskar"
last_name="Vishwakarma"

print("My First Name is {} and last name is {}".format(first_name,last_name))
# Out:
# My First Name is Sanskar and last name is Vishwakarma

# %% [markdown]
# ## len function

# %%
len("Sanskar")
# Out:
# 7
