# %%
lst1=[1,2,3]
lst2=[1,2,3]

lst1==lst2 # True because it compares the values of both the list
# Out:
# True

# %%
lst1=[1,2,3]
lst2=[1,2,3]

lst1 is lst2 # false because both lst1 and lst2 values are stored in different memory location
# Out:
# False

# %%
lst1=[1,2,3]
lst2=lst1

lst1 is lst2 # true because both lst1 and lst2 values are stored in same memory location
# Out:
# True

# %%
lst2[0]="Sanskar"

# %%
lst2
# Out:
# ['Sanskar', 2, 3]

# %%
lst1
# Out:
# ['Sanskar', 2, 3]
