# %% [markdown]
# ## Boolean

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
print(True,False)
# Out:
# True False

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ## Boolean and Logical Operators

# %%
True or False
# Out:
# True

# %%
True and False
# Out:
# False

# %% [markdown]
# ## Lists

# %% [raw]
# List in python is a mutable array and it is dynamic means it can change its length, the elements inside the list is called item

# %%
lst=[]

type(lst)
# Out:
# list

# %%
lst=list()

type(lst)
# Out:
# list

# %%
lst=["Sanskar",12,False]

# %%
len(lst)
# Out:
# 3

# %% [markdown]
# ## Append inside the list (adds value at the end of the list)

# %%
print(lst)
# Out:
# ['Sanskar', 12, False]

# %%
lst.append("Mamta")

# %%
print(lst)
# Out:
# ['Sanskar', 12, False, 'Mamta']

# %%
lst[3]
# Out:
# False

# %% [markdown]
# ## Insert inside the list

# %%
lst.insert(2,100)

print(lst)
# Out:
# ['Sanskar', 12, 100, False, 'Mamta']

# %% [markdown]
# ## Indexing in the list

# %%
lst[:]
# Out:
# ['Sanskar', 12, 100, False, 'Mamta']

# %%
lst[1:2]
# Out:
# [12]

# %% [markdown]
# ## Sum in built function

# %%
lst=[1,2,3,4]

# %%
sum(lst)
# Out:
# 10

# %% [markdown]
# ## Pop function

# %%
lst.pop(2)

lst
# Out:
# [1, 2, 4]

# %% [markdown]
# ## Some in built function

# %%
lst=[1,1,2,3,4,5,6]

# %%
lst.count(1)
# Out:
# 2

# %%
len(lst)
# Out:
# 7

# %%
lst.index(1)  # index returns the first occurrence of an element and we can give the start index and end index which is optional
# Out:
# 0

# %%
lst.index(1,1,4)
# Out:
# 1

# %%
min(lst)
# Out:
# 1

# %%
max(lst)
# Out:
# 6
