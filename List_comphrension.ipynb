# %%
lst1=[]

def sqlist(lst):
    for i in lst:
        lst1.append(i*i)
    return lst1

# %%
sqlist([1,2,3,4])
# Out:
# [1, 4, 9, 16]

# %%
lst=[1,2,3]

# %%
lst1=[i*i for i in lst] # list comphrension

# %%
print(lst1)
# Out:
# [1, 4, 9]
